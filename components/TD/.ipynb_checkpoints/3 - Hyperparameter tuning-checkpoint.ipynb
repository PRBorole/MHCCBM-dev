# %%
# load packages
import numpy as np
import pandas as pd
import seaborn as sns
import time
import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestRegressor,RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

import torch
import esm
from tqdm import tqdm
import pickle

from torchinfo import summary

from sklearn.metrics import f1_score, roc_auc_score, roc_curve, auc, precision_recall_curve
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

import sys
sys.path.append('./../../src/')


from utils import *
from TDPredictor_CNN import *
from MHCCBM import *

import itertools
import json

# %%
hidden_channels_ls = [[1024], [512], [256], [128], [64]]
epochs = 200
batch_size_ls = [8,16,32]
lr_ls = [1e-3, 1e-5]
ksize_ls = [3, 5]
dropout_p_ls = [0, 0.1]

combinations = [i for i in itertools.product(hidden_channels_ls, ksize_ls, batch_size_ls, lr_ls, dropout_p_ls)]
ncombinations = len(combinations)

# for i, (hc, ks, bs, lr, dp) in enumerate(itertools.product(hidden_channels_ls, ksize_ls, batch_size_ls, lr_ls, dropout_p_ls)):
#     print(i, (hc, ks, bs, lr, dp))
    
#     config_dict = { "project" : "MHCCBM",
#                     "name" : "CNN_"+str(i), 
#                     "config" : {
#                         "hidden_channels" : hc,
#                         "epochs" : epochs,
#                         "kernel_size": ks,
#                         "pool_kernel_size":ks,
#                         "classes" : 2,
#                         "seed": 42,
#                         "batch_size" : bs,
#                         "lr" : lr,
#                         "dataset" : "TD bashirova MFI data",
#                         "dropout_p" : dp,
#                         "architecture" : "CNN"}
#                     }
#     with open('./config/hyperparameter_tuning/CNN/config_'+str(i)+'.json','w') as f:
#         json.dump(config_dict,f)


# config_dict = { "project" : "MHCCBM",
#                     "name" : "CNN_"+str(120), 
#                     "config" : {
#                         "hidden_channels" : [256,256],
#                         "epochs" : 200,
#                         "kernel_size": 3,
#                         "pool_kernel_size":3,
#                         "classes" : 2,
#                         "seed": 42,
#                         "batch_size" : 16,
#                         "lr" : 1e-05,
#                         "dataset" : "TD bashirova MFI data",
#                         "dropout_p" : 0.1,
#                         "architecture" : "CNN"}
#                     }
# with open('./config/hyperparameter_tuning/CNN/config_'+str(120)+'.json','w') as f:
#     json.dump(config_dict,f)

# %%
result_df = []

for idx, (hc, ks, bs, lr, dp) in enumerate(itertools.product(hidden_channels_ls, ksize_ls, batch_size_ls, lr_ls, dropout_p_ls)):
    if bs != 8:  
        result_ = pd.read_csv('./results/hyperparameter_tuning_result/CNN/CNN_'+str(idx)+'.csv')
        result_['idx'] = [idx]*len(result_)
        result_df = result_df + [result_]
        
    
result_df = pd.concat(result_df)
result_df
# Out:
#     Unnamed: 0  time_elapsed  epoch  fold  f1_train  auroc_train  auprc_train  \
# 0            0    209.227166   68.0     0  0.927564     0.992593     0.998324
# 1            0    309.909894   87.0     1  0.962938     1.000000     1.000000
# 2            0    265.861054   71.0     2  0.927973     0.995536     0.999038
# 3            0    420.934111  121.0     3  0.916635     0.995536     0.999049
# 4            0    631.299865  175.0     4  0.939451     0.996652     0.999295
# ..         ...           ...    ...   ...       ...          ...          ...
# 5            0     12.775485   54.0     5  0.860851     0.771205     0.902363
# 6            0     14.309277   58.0     6  0.868998     0.867188     0.963553
# 7            0     32.129847  132.0     7  0.862457     0.923958     0.981569
# 8            0     49.889982    NaN     8  0.889887     0.943750     0.986998
# 9            0     47.199283    NaN     9  0.889887     0.953125     0.988762
#
#      f1_test  auroc_test  auprc_test  idx
# 0   0.836601    0.875000    0.985243    4
# 1   0.680556    1.000000    1.000000    4
# 2   0.777778    0.928571    0.980867    4
# 3   0.622222    0.571429    0.883787    4
# 4   0.874074    1.000000    1.000000    4
# ..       ...         ...         ...  ...
# 5   0.555556    0.500000    0.851644  119
# 6   0.680556    0.500000    0.692092  119
# 7   0.673077    0.428571    0.900425  119
# 8   0.891026    1.000000    1.000000  119
# 9   0.566667    1.000000    1.000000  119
#
# [800 rows x 11 columns]

# %%
result_df.groupby('idx').mean().sort_values('f1_test')
# Out:
#      Unnamed: 0  time_elapsed       epoch  fold  f1_train  auroc_train  \
# idx
# 21          0.0    381.388230   73.000000   4.5  0.460161     0.859191
# 11          0.0    506.108491   56.000000   4.5  0.437664     0.890880
# 22          0.0    362.612069   55.571429   4.5  0.443268     0.749744
# 8           0.0    367.569730   78.000000   4.5  0.549875     0.867572
# 44          0.0    169.520346   79.700000   4.5  0.584396     0.830653
# ..          ...           ...         ...   ...       ...          ...
# 89          0.0     62.163067  123.800000   4.5  0.953827     0.998549
# 88          0.0     53.073106  121.700000   4.5  0.956292     0.998452
# 5           0.0    305.179190   88.555556   4.5  0.888210     0.892716
# 117         0.0     26.637917  113.625000   4.5  0.942699     0.995116
# 80          0.0     66.950517  132.666667   4.5  0.939528     0.991800
#
#      auprc_train   f1_test  auroc_test  auprc_test
# idx
# 21      0.958094  0.362340    0.730357    0.883057
# 11      0.968274  0.374544    0.721429    0.900391
# 22      0.911187  0.435210    0.457143    0.809861
# 8       0.957435  0.471446    0.726786    0.919514
# 44      0.948446  0.474680    0.671429    0.888810
# ..           ...       ...         ...         ...
# 89      0.999692  0.791417    0.942857    0.983549
# 88      0.999659  0.791417    0.914286    0.976052
# 5       0.979109  0.800975    0.778571    0.938880
# 117     0.998935  0.808020    0.921429    0.980473
# 80      0.998176  0.814285    0.958929    0.991325
#
# [80 rows x 10 columns]

# %%
combinations[80], combinations[80], combinations[80]
# Out:
# (([128], 3, 32, 0.001, 0), ([128], 3, 32, 0.001, 0), ([128], 3, 32, 0.001, 0))

# %%
pd.read_csv('./results/hyperparameter_tuning_result/CNN/CNN_'+str(121)+'.csv').mean()
# Out:
# Unnamed: 0        0.000000
# time_elapsed    653.995264
# epoch           131.500000
# fold              4.500000
# f1_train          0.794804
# auroc_train       0.920748
# auprc_train       0.907261
# f1_test           0.697193
# auroc_test        0.780000
# auprc_test        0.743254
# dtype: float64
